# %% [markdown]
# ### Load Kaggle Dataset
# <b> Prerequisites: </b>
# - Python 3.6 or higher
# - kaggle package installed (`pip install kaggle`)
# - Kaggle API credentials set up (kaggle.json file in the correct location)
